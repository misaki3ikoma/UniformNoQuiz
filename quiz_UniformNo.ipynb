# %%
# !pip install streamlit

# %%
# !pip install openpyxl

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive/ikoma/quiz_UniformNo')

# %%
from google.colab import files
files.view("quiz_UniformNo.py")

# %%
# !streamlit run quiz_UniformNo.py & sleep 3 && npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.74.134.167:8501
#
# npx: installed 22 in 4.16s
# your url is: https://swift-mirrors-clap.loca.lt
